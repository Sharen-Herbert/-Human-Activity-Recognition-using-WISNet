# %%
import pandas as pd
import numpy as np 
from numpy import mean
from numpy import std
from numpy import dstack
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import LSTM,GRU,SimpleRNN
from keras.utils import to_categorical
from matplotlib import pyplot
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Out:
# Using TensorFlow backend.

# %%
DATA_PATH = 'WISDM.txt'
COLUMN_NAMES = [
    'user',
    'activity',
    'timestamp',
    'x-axis',
    'y-axis',
    'z-axis'
]

LABELS = [
    'Downstairs',
    'Jogging',
    'Sitting',
    'Standing',
    'Upstairs',
    'Walking'
]

# %%
def plot_activity(activity,df,start=0,stop=200):
    
    extractRowsOfActivity = (df['activity'] == activity)  # Output will be true/false.
    data = df[extractRowsOfActivity] # data has only rows that are for the requested activity.
    data = data[['x-axis','y-axis','z-axis']] # data has only the accelerometer columns.
    data = data[start:stop]
  
    ax = data.plot(subplots=True,figsize=(12,6),color=['hotpink','lightcoral','purple'],title=activity+ ', Start Row: '+str(start)+' Stop row: '+str(stop)) # Plot accelerometer for the activity.

# %%
df = pd.read_csv(DATA_PATH, header=None, names=COLUMN_NAMES)
df.dropna()
# Out:
#          user activity        timestamp    x-axis     y-axis        z-axis
# 0          33  Jogging   49105962326000 -0.694638  12.680544   0.50395286;
# 1          33  Jogging   49106062271000  5.012288  11.264028   0.95342433;
# 2          33  Jogging   49106112167000  4.903325  10.882658  -0.08172209;
# 3          33  Jogging   49106222305000 -0.612916  18.496431    3.0237172;
# 4          33  Jogging   49106332290000 -1.184970  12.108489     7.205164;
# ...       ...      ...              ...       ...        ...           ...
# 1098199    19  Sitting  131623331483000  9.000000  -1.570000         1.69;
# 1098200    19  Sitting  131623371431000  9.040000  -1.460000         1.73;
# 1098201    19  Sitting  131623411592000  9.080000  -1.380000         1.69;
# 1098202    19  Sitting  131623491487000  9.000000  -1.460000         1.73;
# 1098203    19  Sitting  131623531465000  8.880000  -1.330000         1.61;
#
# [1098203 rows x 6 columns]

# %%
df['z-axis'] = df['z-axis'].str.replace(';', '')
df['z-axis'] = df['z-axis'].apply(lambda x:float(x))

# %%
plot_activity('Sitting',df,200,500)
plot_activity('Walking',df,200,500)
plot_activity('Upstairs',df,200,500)
plot_activity('Downstairs',df,200,500)
plot_activity('Jogging',df,200,500)
plot_activity('Standing',df,200,500)

# %%
RANDOM_SEED = 13
N_TIME_STEPS = 50
N_FEATURES = 3
step = 10
segments = []
labels = []
N_CLASSES = 6
N_HIDDEN_UNITS = 64
N_EPOCHS = 20
BATCH_SIZE = 1024
LEARNING_RATE = 0.1
L2_LOSS = 0.0015

# %%
def readData(DATA_PATH,COLUMN_NAMES,LABELS):
    data = pd.read_csv(DATA_PATH, header=None, names=COLUMN_NAMES)
    data['z-axis'].replace({';': ''}, regex=True, inplace=True)
    data['z-axis']=pd.to_numeric(data['z-axis'],errors='coerce')
    data = data.dropna() 
    return data
def plotActivity(data,activity,rowsSize,subPlotObj,subPlotTitle):
    activityX= data[data['activity'] == activity][['x-axis']][:rowsSize]
    activityY= data[data['activity'] == activity][['y-axis']][:rowsSize]
    activityZ= data[data['activity'] == activity][['z-axis']][:rowsSize]
    subPlotObj.plot(activityX, label='X')
    subPlotObj.plot(activityY,'--', label='Y')
    subPlotObj.plot(activityZ, label='Z')
    subPlotObj.set_title(subPlotTitle)
    subPlotObj.legend()
def plot_correlation(df,subPlotObj,subPlotTitle):   
   sns.heatmap(df.corr(),cmap="YlGnBu",cbar=True,ax=subPlotObj)
   tl = subPlotObj.get_xticklabels()
   subPlotObj.set_xticklabels(tl, rotation=90)
   tly = subPlotObj.get_yticklabels()
   subPlotObj.set_yticklabels(tly, rotation=0)
   subPlotObj.set_title(subPlotTitle)
def create_mixed_Df(activity1, activity2,subPlotObj):
    activity1X=projectData[projectData['activity'] == activity1]['x-axis'][:]
    activity1Y= projectData[projectData['activity'] == activity1]['y-axis'][:]
    activity1Z=projectData[projectData['activity'] == activity1]['z-axis'][:]
    activity2X=projectData[projectData['activity'] == activity2]['x-axis'][:]
    activity2Y= projectData[projectData['activity'] == activity2]['y-axis'][:]
    activity2Z=projectData[projectData['activity'] == activity2]['z-axis'][:]
    list_of_tuples = list(zip(activity1X,activity1Y,activity1Z, activity2X,activity2Y,activity2Z))      
    df = pd.DataFrame(list_of_tuples, columns = [activity1+'X', activity1+'Y',activity1+'Z',activity2+'X',activity2+'Y',activity2+'Z'])

# %%
projectData=readData(DATA_PATH,COLUMN_NAMES,LABELS)

# %%
#create segements each segement contains 50 (N_TIME_STEPS) activity records and interval 10 (step) stepsize
labels=[]
segments=[]
for i in range(0, len(projectData) - N_TIME_STEPS, step):
    xs = projectData['x-axis'].values[i: i + N_TIME_STEPS]
    ys = projectData['y-axis'].values[i: i + N_TIME_STEPS]
    zs = projectData['z-axis'].values[i: i + N_TIME_STEPS]
    label = stats.mode(projectData['activity'][i: i + N_TIME_STEPS])[0][0]
    segments.append([xs, ys, zs])
    
    labels.append(label)

from collections import Counter

# Sample array with 6 elements
array =labels # Replace with your actual array

# Calculate the count of each element using Counter
element_counts = Counter(array)

# Print the counts for each element
for element, count in element_counts.items():
    print(f"Element {element}: {count}")
print(len(segments),len(labels))
#reshape the segments which is (list of arrays) to one list
reshaped_segments = np.asarray(segments, dtype= np.float32).reshape(-1, N_TIME_STEPS, N_FEATURES)
labels = np.asarray(pd.get_dummies(labels), dtype = np.float32)
# Out:
# Element Jogging: 34225
# Element Walking: 42433
# Element Upstairs: 12274
# Element Downstairs: 10056
# Element Sitting: 5989
# Element Standing: 4839
# 109816 109816

# %%
X_train, X_test, y_train, y_test = train_test_split(
        reshaped_segments, labels, test_size=0.2, random_state=RANDOM_SEED)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (87852, 50, 3)
# (21964, 50, 3)
# (87852, 6)
# (21964, 6)

# %% [markdown]
# # GRU

# %%
def display_history(history_):
    fig, ax = plt.subplots(1,2, figsize=(12, 3))
    ax[0].plot(history_.history['loss'], color='b', label="training_loss")
    ax[0].plot(history_.history['val_loss'], color='r', label="validation_loss",axes =ax[0])
    ax[0].set_xlabel("Epoch")
    ax[0].set_ylabel("Loss")
    legend = ax[0].legend(loc='best', shadow=True)
    ax[1].plot(history_.history['accuracy'], color='b', label="training_accuracy")
    ax[1].plot(history_.history['val_accuracy'], color='r',label="validation_accuracy")
    ax[1].set_xlabel("Epoch")
    ax[1].set_ylabel("Accuracy")
    legend = ax[1].legend(loc='best', shadow=True)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

def plot_metrices(model_):
    # Predicting the test data
    pred = model_.predict(X_test, batch_size=BATCH_SIZE)
    pred_class_indices = np.argmax(pred, axis=1)  # Convert predictions to class indices
    
    # Compute confusion matrix
    cm = confusion_matrix(y_test.argmax(axis=1), pred_class_indices)
    
    # Define classes for plotting
    classes = ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']
    
    # Plot the confusion matrix
    plt.figure()
    ax = plt.subplot()
    ax.set_title('Confusion Matrix')
    
    sns.heatmap(cm, annot=True, fmt='d', xticklabels=classes, yticklabels=classes, cmap='Reds')
    
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    
    print(classification_report(y_test.argmax(axis=1), pred_class_indices, target_names=classes))

    # Calculate total samples
    total = cm.sum()
    
    accuracy = np.trace(cm) / total  # Total correct predictions divided by total samples
    sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])  # True positive rate for the first class
    specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])  # True negative rate for the second class

    print(f"ACC: {accuracy:.4f}")
    print(f"Sensitivity: {sensitivity:.4f}")
    print(f"Specificity: {specificity:.4f}")

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dropout, Dense

from tensorflow.keras.layers import Dense

epochs, batch_size = 30, 1024

model = Sequential()

model.add(GRU(100, input_shape=(X_train.shape[1], X_train.shape[2])))

model.add(Dropout(0.3))

model.add(Dense(100, activation='relu'))
model.add(Dense(y_train.shape[1], activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 100)               31500
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_18 (Dense)             (None, 6)                 606
# =================================================================
# Total params: 42,206
# Trainable params: 42,206
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=epochs, validation_split=0.25,batch_size=batch_size,verbose=1)
# Out:
# Train on 65889 samples, validate on 21963 samples
# Epoch 1/30
# 65889/65889 [==============================] - 2s 34us/sample - loss: 1.1830 - accuracy: 0.5330 - val_loss: 0.6459 - val_accuracy: 0.7806
# Epoch 2/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.5466 - accuracy: 0.8065 - val_loss: 0.4787 - val_accuracy: 0.8267
# Epoch 3/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.4699 - accuracy: 0.8303 - val_loss: 0.4336 - val_accuracy: 0.8425
# Epoch 4/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.4333 - accuracy: 0.8430 - val_loss: 0.4018 - val_accuracy: 0.8573
# Epoch 5/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.3971 - accuracy: 0.8560 - val_loss: 0.3760 - val_accuracy: 0.8688
# Epoch 6/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.3661 - accuracy: 0.8694 - val_loss: 0.3389 - val_accuracy: 0.8791
# Epoch 7/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.3323 - accuracy: 0.8839 - val_loss: 0.3092 - val_accuracy: 0.8908
# Epoch 8/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.3021 - accuracy: 0.8946 - val_loss: 0.2829 - val_accuracy: 0.9042
# Epoch 9/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.2759 - accuracy: 0.9048 - val_loss: 0.2548 - val_accuracy: 0.9122
# Epoch 10/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.2640 - accuracy: 0.9093 - val_loss: 0.2495 - val_accuracy: 0.9147
# Epoch 11/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.2392 - accuracy: 0.9184 - val_loss: 0.2265 - val_accuracy: 0.9222
# Epoch 12/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.2253 - accuracy: 0.9232 - val_loss: 0.2136 - val_accuracy: 0.9264
# Epoch 13/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.2126 - accuracy: 0.9282 - val_loss: 0.2020 - val_accuracy: 0.9317
# Epoch 14/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.2031 - accuracy: 0.9313 - val_loss: 0.1916 - val_accuracy: 0.9359
# Epoch 15/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1939 - accuracy: 0.9354 - val_loss: 0.1808 - val_accuracy: 0.9402
# Epoch 16/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1829 - accuracy: 0.9390 - val_loss: 0.2081 - val_accuracy: 0.9333
# Epoch 17/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1782 - accuracy: 0.9402 - val_loss: 0.1755 - val_accuracy: 0.9436
# Epoch 18/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1685 - accuracy: 0.9437 - val_loss: 0.1801 - val_accuracy: 0.9427
# Epoch 19/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1681 - accuracy: 0.9435 - val_loss: 0.1636 - val_accuracy: 0.9452
# Epoch 20/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1577 - accuracy: 0.9472 - val_loss: 0.1576 - val_accuracy: 0.9484
# Epoch 21/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.1527 - accuracy: 0.9495 - val_loss: 0.1508 - val_accuracy: 0.9508
# Epoch 22/30
# 65889/65889 [==============================] - 1s 13us/sample - loss: 0.1478 - accuracy: 0.9506 - val_loss: 0.1529 - val_accuracy: 0.9513
# Epoch 23/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.1425 - accuracy: 0.9531 - val_loss: 0.1528 - val_accuracy: 0.9475
# Epoch 24/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1369 - accuracy: 0.9546 - val_loss: 0.1411 - val_accuracy: 0.9541
# Epoch 25/30
# 65889/65889 [==============================] - 1s 12us/sample - loss: 0.1310 - accuracy: 0.9563 - val_loss: 0.1387 - val_accuracy: 0.9545
# Epoch 26/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1304 - accuracy: 0.9570 - val_loss: 0.1630 - val_accuracy: 0.9485
# Epoch 27/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1295 - accuracy: 0.9572 - val_loss: 0.1397 - val_accuracy: 0.9545
# Epoch 28/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1243 - accuracy: 0.9587 - val_loss: 0.1368 - val_accuracy: 0.9564
# Epoch 29/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1182 - accuracy: 0.9616 - val_loss: 0.1370 - val_accuracy: 0.9567
# Epoch 30/30
# 65889/65889 [==============================] - 1s 11us/sample - loss: 0.1163 - accuracy: 0.9623 - val_loss: 0.1345 - val_accuracy: 0.9575

# %%
_, accuracy = model.evaluate(X_test, y_test, batch_size=batch_size, verbose=1)
accuracy
# Out:
# 21964/21964 [==============================] - 0s 9us/step
# 0.9491440653800964

# %%
from keras.models import load_model
model.save('harmodel.h5')  # creates a HDF5 file 'my_model.h5'

with open('model_architecture.json', 'w') as f:
    f.write(model.to_json())

# %%
display_history(history)
plot_metrices(model)
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.78      0.91      0.84      2012
#      Jogging       0.99      0.98      0.98      6940
#      Sitting       1.00      0.99      0.99      1226
#     Standing       0.98      0.98      0.98       969
#     Upstairs       0.84      0.81      0.83      2439
#      Walking       0.99      0.97      0.98      8378
#
#     accuracy                           0.95     21964
#    macro avg       0.93      0.94      0.93     21964
# weighted avg       0.95      0.95      0.95     21964
#
# ACC: 0.9491
# Sensitivity: 0.9956
# Specificity: 0.9944

# %%
import sklearn.metrics
def plot_roc(model_, name):
    plt.figure()
    ax = plt.subplot()
    ax.set_title('ROC Curve')
    pred = model_.predict(X_test).ravel()
    print(pred.size)
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test.ravel(), pred)
    ac = sklearn.metrics.auc(fpr, tpr)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='{} (area = {:.3f})'.format(name, ac))
    plt.xlabel('False positive rate(100-Specificity)')
    plt.ylabel('True positive rate(Sensitivity)')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show
plot_roc(model,"GRU")
# Out:
# 131784

# %%
LABELS = ['Downstairs', 'Jogging', 'Sitting', 'Standing', 'Upstairs', 'Walking']
y_pred = model.predict(X_test)
matrix = confusion_matrix(y_test.argmax(axis=1),y_pred.argmax(axis=1))

# %% [markdown]
# # **LSTM**

# %%
epochs, batch_size =  30, 1024
model2 = Sequential()
model2.add(LSTM(100, input_shape=(X_train.shape[1],X_train.shape[2])))
model2.add(Dropout(0.3))
model2.add(Dense(100, activation='relu'))
model2.add(Dense(y_train.shape[1], activation='softmax'))
model2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               41600
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_6 (Dense)              (None, 6)                 606
# =================================================================
# Total params: 52,306
# Trainable params: 52,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(X_train, y_train, epochs=epochs, validation_split=0.25,batch_size=batch_size,verbose=1)
# Out:
# Train on 65889 samples, validate on 21963 samples
# Epoch 1/30
# 65889/65889 [==============================] - 3s 49us/step - loss: 0.9750 - accuracy: 0.6529 - val_loss: 0.5490 - val_accuracy: 0.8091
# Epoch 2/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.5204 - accuracy: 0.8175 - val_loss: 0.4661 - val_accuracy: 0.8339
# Epoch 3/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.4617 - accuracy: 0.8360 - val_loss: 0.4320 - val_accuracy: 0.8409
# Epoch 4/30
# 65889/65889 [==============================] - 3s 42us/step - loss: 0.4180 - accuracy: 0.8484 - val_loss: 0.3991 - val_accuracy: 0.8502
# Epoch 5/30
# 65889/65889 [==============================] - 3s 43us/step - loss: 0.3832 - accuracy: 0.8588 - val_loss: 0.3390 - val_accuracy: 0.8742
# Epoch 6/30
# 65889/65889 [==============================] - 3s 42us/step - loss: 0.3462 - accuracy: 0.8728 - val_loss: 0.3106 - val_accuracy: 0.8848
# Epoch 7/30
# 65889/65889 [==============================] - 3s 40us/step - loss: 0.3183 - accuracy: 0.8812 - val_loss: 0.2945 - val_accuracy: 0.8909
# Epoch 8/30
# 65889/65889 [==============================] - 3s 40us/step - loss: 0.3037 - accuracy: 0.8864 - val_loss: 0.2850 - val_accuracy: 0.8959
# Epoch 9/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.2823 - accuracy: 0.8960 - val_loss: 0.2831 - val_accuracy: 0.8943
# Epoch 10/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.2805 - accuracy: 0.8965 - val_loss: 0.2634 - val_accuracy: 0.9001
# Epoch 11/30
# 65889/65889 [==============================] - 3s 40us/step - loss: 0.2608 - accuracy: 0.9039 - val_loss: 0.2482 - val_accuracy: 0.9102
# Epoch 12/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.2438 - accuracy: 0.9104 - val_loss: 0.2397 - val_accuracy: 0.9148
# Epoch 13/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.2337 - accuracy: 0.9147 - val_loss: 0.2352 - val_accuracy: 0.9154
# Epoch 14/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.2248 - accuracy: 0.9190 - val_loss: 0.2126 - val_accuracy: 0.9231
# Epoch 15/30
# 65889/65889 [==============================] - 3s 42us/step - loss: 0.2157 - accuracy: 0.9221 - val_loss: 0.2121 - val_accuracy: 0.9262
# Epoch 16/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.2028 - accuracy: 0.9277 - val_loss: 0.1999 - val_accuracy: 0.9291
# Epoch 17/30
# 65889/65889 [==============================] - 3s 43us/step - loss: 0.1955 - accuracy: 0.9299 - val_loss: 0.1919 - val_accuracy: 0.9323
# Epoch 18/30
# 65889/65889 [==============================] - 3s 40us/step - loss: 0.1854 - accuracy: 0.9340 - val_loss: 0.1987 - val_accuracy: 0.9313
# Epoch 19/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1842 - accuracy: 0.9357 - val_loss: 0.1959 - val_accuracy: 0.9347
# Epoch 20/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1730 - accuracy: 0.9403 - val_loss: 0.1846 - val_accuracy: 0.9386
# Epoch 21/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1728 - accuracy: 0.9392 - val_loss: 0.1964 - val_accuracy: 0.9352
# Epoch 22/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1642 - accuracy: 0.9423 - val_loss: 0.1831 - val_accuracy: 0.9354
# Epoch 23/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1582 - accuracy: 0.9452 - val_loss: 0.1723 - val_accuracy: 0.9404
# Epoch 24/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1523 - accuracy: 0.9479 - val_loss: 0.1727 - val_accuracy: 0.9443
# Epoch 25/30
# 65889/65889 [==============================] - 3s 42us/step - loss: 0.1468 - accuracy: 0.9482 - val_loss: 0.1584 - val_accuracy: 0.9477
# Epoch 26/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1410 - accuracy: 0.9517 - val_loss: 0.1666 - val_accuracy: 0.9468
# Epoch 27/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1383 - accuracy: 0.9532 - val_loss: 0.1511 - val_accuracy: 0.9510
# Epoch 28/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1330 - accuracy: 0.9545 - val_loss: 0.1757 - val_accuracy: 0.9453
# Epoch 29/30
# 65889/65889 [==============================] - 3s 41us/step - loss: 0.1342 - accuracy: 0.9542 - val_loss: 0.1844 - val_accuracy: 0.9423
# Epoch 30/30
# 65889/65889 [==============================] - 3s 40us/step - loss: 0.1264 - accuracy: 0.9570 - val_loss: 0.1456 - val_accuracy: 0.9521

# %%
_, accuracy = model2.evaluate(X_test, y_test, batch_size=batch_size, verbose=1)
accuracy
# Out:
# 21964/21964 [==============================] - 0s 9us/step
# 0.9512839317321777

# %%
display_history(history2)
plot_metrices(model2)
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.83      0.87      0.85      2012
#      Jogging       0.99      0.99      0.99      6940
#      Sitting       1.00      0.99      0.99      1226
#     Standing       0.99      0.99      0.99       969
#     Upstairs       0.87      0.80      0.83      2439
#      Walking       0.97      0.98      0.97      8378
#
#     accuracy                           0.95     21964
#    macro avg       0.94      0.93      0.94     21964
# weighted avg       0.95      0.95      0.95     21964
#
# ACC: 0.9513
# Sensitivity: 0.9876
# Specificity: 0.9974

# %%
import sklearn.metrics
def plot_roc(model_, name):
    plt.figure()
    ax = plt.subplot()
    ax.set_title('ROC Curve')
    pred = model_.predict(X_test).ravel()
    print(pred.size)
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test.ravel(), pred)
    ac = sklearn.metrics.auc(fpr, tpr)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='{} (area = {:.3f})'.format(name, ac))
    plt.xlabel('False positive rate(100-Specificity)')
    plt.ylabel('True positive rate(Sensitivity)')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show
plot_roc(model2,"LSTM")
# Out:
# 131784

# %% [markdown]
# # Simple RNN

# %%
epochs, batch_size =  30, 1024
model3 = Sequential()
model3.add(SimpleRNN(100, input_shape=(X_train.shape[1],X_train.shape[2])))
model3.add(Dropout(0.3))
model3.add(Dense(100, activation='relu'))
model3.add(Dense(y_train.shape[1], activation='softmax'))
model3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_1 (SimpleRNN)     (None, 100)               10400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 606
# =================================================================
# Total params: 21,106
# Trainable params: 21,106
# Non-trainable params: 0
# _________________________________________________________________

# %%
history3 = model3.fit(X_train, y_train, epochs=epochs, validation_split=0.25,batch_size=batch_size,verbose=1)
# Out:
# Train on 65889 samples, validate on 21963 samples
# Epoch 1/30
# 65889/65889 [==============================] - 2s 27us/step - loss: 1.2255 - accuracy: 0.5262 - val_loss: 0.8439 - val_accuracy: 0.7066
# Epoch 2/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.7636 - accuracy: 0.7349 - val_loss: 0.5888 - val_accuracy: 0.7964
# Epoch 3/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.5531 - accuracy: 0.8091 - val_loss: 0.4615 - val_accuracy: 0.8346
# Epoch 4/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.4699 - accuracy: 0.8364 - val_loss: 0.4098 - val_accuracy: 0.8527
# Epoch 5/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.4339 - accuracy: 0.8494 - val_loss: 0.4038 - val_accuracy: 0.8574
# Epoch 6/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.4123 - accuracy: 0.8563 - val_loss: 0.3748 - val_accuracy: 0.8658
# Epoch 7/30
# 65889/65889 [==============================] - 1s 21us/step - loss: 0.3919 - accuracy: 0.8625 - val_loss: 0.3655 - val_accuracy: 0.8713
# Epoch 8/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3751 - accuracy: 0.8681 - val_loss: 0.3579 - val_accuracy: 0.8716
# Epoch 9/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3663 - accuracy: 0.8713 - val_loss: 0.3403 - val_accuracy: 0.8790
# Epoch 10/30
# 65889/65889 [==============================] - 1s 21us/step - loss: 0.3594 - accuracy: 0.8733 - val_loss: 0.3396 - val_accuracy: 0.8783
# Epoch 11/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3500 - accuracy: 0.8766 - val_loss: 0.3317 - val_accuracy: 0.8798
# Epoch 12/30
# 65889/65889 [==============================] - 1s 21us/step - loss: 0.3314 - accuracy: 0.8827 - val_loss: 0.3211 - val_accuracy: 0.8864
# Epoch 13/30
# 65889/65889 [==============================] - 2s 24us/step - loss: 0.3449 - accuracy: 0.8783 - val_loss: 0.3250 - val_accuracy: 0.8837
# Epoch 14/30
# 65889/65889 [==============================] - 2s 23us/step - loss: 0.3251 - accuracy: 0.8847 - val_loss: 0.3175 - val_accuracy: 0.8879
# Epoch 15/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3166 - accuracy: 0.8886 - val_loss: 0.3193 - val_accuracy: 0.8872
# Epoch 16/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3223 - accuracy: 0.8863 - val_loss: 0.3072 - val_accuracy: 0.8902
# Epoch 17/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3145 - accuracy: 0.8881 - val_loss: 0.3002 - val_accuracy: 0.8936
# Epoch 18/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3002 - accuracy: 0.8924 - val_loss: 0.3061 - val_accuracy: 0.8931
# Epoch 19/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2968 - accuracy: 0.8937 - val_loss: 0.3015 - val_accuracy: 0.8949
# Epoch 20/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.3011 - accuracy: 0.8929 - val_loss: 0.2987 - val_accuracy: 0.8928
# Epoch 21/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2923 - accuracy: 0.8967 - val_loss: 0.2900 - val_accuracy: 0.8977
# Epoch 22/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2814 - accuracy: 0.8989 - val_loss: 0.2821 - val_accuracy: 0.8977
# Epoch 23/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2985 - accuracy: 0.8929 - val_loss: 0.2958 - val_accuracy: 0.8935
# Epoch 24/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2791 - accuracy: 0.9012 - val_loss: 0.2891 - val_accuracy: 0.8966
# Epoch 25/30
# 65889/65889 [==============================] - 1s 23us/step - loss: 0.2709 - accuracy: 0.9037 - val_loss: 0.2841 - val_accuracy: 0.9015
# Epoch 26/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2657 - accuracy: 0.9046 - val_loss: 0.2845 - val_accuracy: 0.8961
# Epoch 27/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2632 - accuracy: 0.9065 - val_loss: 0.2909 - val_accuracy: 0.8940
# Epoch 28/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2673 - accuracy: 0.9041 - val_loss: 0.2756 - val_accuracy: 0.9038
# Epoch 29/30
# 65889/65889 [==============================] - 1s 22us/step - loss: 0.2594 - accuracy: 0.9067 - val_loss: 0.2873 - val_accuracy: 0.9006
# Epoch 30/30
# 65889/65889 [==============================] - 1s 23us/step - loss: 0.2540 - accuracy: 0.9079 - val_loss: 0.2629 - val_accuracy: 0.9065

# %%
_, accuracy = model3.evaluate(X_test, y_test, batch_size=batch_size, verbose=1)
accuracy
# Out:
# 21964/21964 [==============================] - 0s 5us/step
# 0.9046621918678284

# %%
display_history(history3)
plot_metrices(model3)
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.77      0.54      0.63      2012
#      Jogging       0.97      0.98      0.97      6940
#      Sitting       0.99      0.99      0.99      1226
#     Standing       0.98      0.97      0.98       969
#     Upstairs       0.66      0.72      0.69      2439
#      Walking       0.93      0.96      0.95      8378
#
#     accuracy                           0.90     21964
#    macro avg       0.88      0.86      0.87     21964
# weighted avg       0.90      0.90      0.90     21964
#
# ACC: 0.9047
# Sensitivity: 0.9792
# Specificity: 0.9974

# %%
import sklearn.metrics
def plot_roc(model_, name):
    plt.figure()
    ax = plt.subplot()
    ax.set_title('ROC Curve')
    pred = model_.predict(X_test).ravel()
    print(pred.size)
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test.ravel(), pred)
    ac = sklearn.metrics.auc(fpr, tpr)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='{} (area = {:.3f})'.format(name, ac))
    plt.xlabel('False positive rate(100-Specificity)')
    plt.ylabel('True positive rate(Sensitivity)')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show
plot_roc(model3,"RNN")
# Out:
# 131784

# %% [markdown]
# # Wisnet

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv1D, BatchNormalization, ReLU, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Multiply, Add, Activation, MaxPooling1D, Concatenate, Input

# Convolved Normalized Pooled (CNPM) Block
def cnpm_block(inputs, filters, kernel_size=5, pool_size=2):
    x = Conv1D(filters, kernel_size, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    # x = MaxPooling1D(pool_size)(x)
    return x

# Identity Block
def identity_block(inputs, filters, kernel_size):
    x = Conv1D(filters, kernel_size, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

# Basic Block
def basic_block(inputs, filters, kernel_size):
    x = Conv1D(filters, kernel_size, padding='same')(inputs)
    x = BatchNormalization()(x)
    # x = ReLU()(x)
    return x

# Identity and Basic (IDBN) Block
def identity_basic_block(inputs, filters, kernel_sizes=[3, 5, 7]):
    idb_outputs = []

    for kernel_size in kernel_sizes:
        id_output = identity_block(inputs, filters, kernel_size)
        id_output = identity_block(id_output, filters, kernel_size)
        basic_output = basic_block(id_output, filters, kernel_size)
        combined_output = Add()([inputs, basic_output])
        combined_output = ReLU()(combined_output)
        idb_outputs.append(combined_output)

    if len(idb_outputs) > 1:
        idb_combined = Add()(idb_outputs)
    else:
        idb_combined = idb_outputs[0]
    
    return idb_combined

# Channel Attention Block
def channel_attention(inputs, reduction_ratio=16):
    channel = inputs.shape[-1]
    
    # Global Average Pooling
    channel_avg_pool = GlobalAveragePooling1D()(inputs)
    channel_max_pool = GlobalMaxPooling1D()(inputs)

    shared_dense_1 = Dense(channel // reduction_ratio, activation='relu')
    shared_dense_2 = Dense(channel, activation='sigmoid')

    avg_out = shared_dense_2(shared_dense_1(channel_avg_pool))
    max_out = shared_dense_2(shared_dense_1(channel_max_pool))

    # Combine the outputs of average and max pooling
    combined_out = Add()([avg_out, max_out])
    combined_out = tf.expand_dims(combined_out, axis=1)

    # Apply the attention weights to the input features
    channel_attention_output = Multiply()([inputs, combined_out])
    return channel_attention_output

# Spatial Attention Block
def spatial_attention(inputs):
    avg_pool = tf.reduce_mean(inputs, axis=-1, keepdims=True)
    max_pool = tf.reduce_max(inputs, axis=-1, keepdims=True)

    concat = tf.concat([avg_pool, max_pool], axis=-1)
    spatial_attention = Conv1D(1, 7, padding='same', activation='sigmoid')(concat)

    # Apply the attention weights to the input features
    spatial_attention_output = Multiply()([inputs, spatial_attention])
    return spatial_attention_output

# Channel and Spatial Attention (CASb) Block
def channel_spatial_attention_block(inputs, reduction_ratio=16):
    x = channel_attention(inputs, reduction_ratio)
    x = spatial_attention(x)
    return x

# WISNet Block
def wisnet_block(inputs, filters, kernel_sizes=[3, 5, 7], reduction_ratio=16):
    x = identity_basic_block(inputs, filters, kernel_sizes)
    x = channel_spatial_attention_block(x, reduction_ratio)
    return x

# Building the WISNet Model
def build_wisnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # CNPM Block
    y = cnpm_block(inputs, 64, kernel_size=5)

    # IDBN1 Block
    x = identity_basic_block(y, 64, kernel_sizes=[3, 5, 7])

    # CASb Block
    x = channel_spatial_attention_block(x, reduction_ratio=16)
    x = Add()([x, y])

    # IDBN2 Block
    x = identity_basic_block(x, 64, kernel_sizes=[3, 5, 7])

    # CASb Block
#     x = channel_spatial_attention_block(x, reduction_ratio=16)

    # Global Pooling and Output Layer
    x = GlobalAveragePooling1D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, x)
    return model

# Define model parameters
input_shape = (X_train.shape[1],X_train.shape[2]) # Assuming 1D signal with length 50 and 64 channels
num_classes = 6        # Adjust based on the classification task

# Build and summarize the model
model4 = build_wisnet(input_shape, num_classes)
model4.summary()
model4.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 50, 3)]      0
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 50, 64)       1024        input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 50, 64)       256         conv1d_76[0][0]
# __________________________________________________________________________________________________
# re_lu_69 (ReLU)                 (None, 50, 64)       0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 50, 64)       12352       re_lu_69[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 50, 64)       20544       re_lu_69[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 50, 64)       28736       re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 50, 64)       256         conv1d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 50, 64)       256         conv1d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 50, 64)       256         conv1d_83[0][0]
# __________________________________________________________________________________________________
# re_lu_70 (ReLU)                 (None, 50, 64)       0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# re_lu_73 (ReLU)                 (None, 50, 64)       0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# re_lu_76 (ReLU)                 (None, 50, 64)       0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 50, 64)       12352       re_lu_70[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 50, 64)       20544       re_lu_73[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 50, 64)       28736       re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 50, 64)       256         conv1d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 50, 64)       256         conv1d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 50, 64)       256         conv1d_84[0][0]
# __________________________________________________________________________________________________
# re_lu_71 (ReLU)                 (None, 50, 64)       0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# re_lu_74 (ReLU)                 (None, 50, 64)       0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# re_lu_77 (ReLU)                 (None, 50, 64)       0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 50, 64)       12352       re_lu_71[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 50, 64)       20544       re_lu_74[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 50, 64)       28736       re_lu_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 50, 64)       256         conv1d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 50, 64)       256         conv1d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 50, 64)       256         conv1d_85[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 50, 64)       0           re_lu_69[0][0]
#                                                                  batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 50, 64)       0           re_lu_69[0][0]
#                                                                  batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 50, 64)       0           re_lu_69[0][0]
#                                                                  batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# re_lu_72 (ReLU)                 (None, 50, 64)       0           add_39[0][0]
# __________________________________________________________________________________________________
# re_lu_75 (ReLU)                 (None, 50, 64)       0           add_40[0][0]
# __________________________________________________________________________________________________
# re_lu_78 (ReLU)                 (None, 50, 64)       0           add_41[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 50, 64)       0           re_lu_72[0][0]
#                                                                  re_lu_75[0][0]
#                                                                  re_lu_78[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_9 (Glo (None, 64)           0           add_42[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_6 (GlobalM (None, 64)           0           add_42[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 4)            260         global_average_pooling1d_9[0][0]
#                                                                  global_max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 64)           320         dense_19[0][0]
#                                                                  dense_19[1][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, 64)           0           dense_20[0][0]
#                                                                  dense_20[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_6 (Tenso [(None, 1, 64)]      0           add_43[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 50, 64)       0           add_42[0][0]
#                                                                  tf_op_layer_ExpandDims_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_6 (TensorFlowO [(None, 50, 1)]      0           multiply_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Max_6 (TensorFlowOp [(None, 50, 1)]      0           multiply_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_6 (TensorFlo [(None, 50, 2)]      0           tf_op_layer_Mean_6[0][0]
#                                                                  tf_op_layer_Max_6[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 50, 1)        15          tf_op_layer_concat_6[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 50, 64)       0           multiply_12[0][0]
#                                                                  conv1d_86[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, 50, 64)       0           multiply_13[0][0]
#                                                                  re_lu_69[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 50, 64)       12352       add_44[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 50, 64)       20544       add_44[0][0]
# __________________________________________________________________________________________________
# conv1d_93 (Conv1D)              (None, 50, 64)       28736       add_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 50, 64)       256         conv1d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 50, 64)       256         conv1d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 50, 64)       256         conv1d_93[0][0]
# __________________________________________________________________________________________________
# re_lu_79 (ReLU)                 (None, 50, 64)       0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# re_lu_82 (ReLU)                 (None, 50, 64)       0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# re_lu_85 (ReLU)                 (None, 50, 64)       0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 50, 64)       12352       re_lu_79[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 50, 64)       20544       re_lu_82[0][0]
# __________________________________________________________________________________________________
# conv1d_94 (Conv1D)              (None, 50, 64)       28736       re_lu_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 50, 64)       256         conv1d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 50, 64)       256         conv1d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 50, 64)       256         conv1d_94[0][0]
# __________________________________________________________________________________________________
# re_lu_80 (ReLU)                 (None, 50, 64)       0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# re_lu_83 (ReLU)                 (None, 50, 64)       0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# re_lu_86 (ReLU)                 (None, 50, 64)       0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 50, 64)       12352       re_lu_80[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 50, 64)       20544       re_lu_83[0][0]
# __________________________________________________________________________________________________
# conv1d_95 (Conv1D)              (None, 50, 64)       28736       re_lu_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 50, 64)       256         conv1d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 50, 64)       256         conv1d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 50, 64)       256         conv1d_95[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, 50, 64)       0           add_44[0][0]
#                                                                  batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, 50, 64)       0           add_44[0][0]
#                                                                  batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, 50, 64)       0           add_44[0][0]
#                                                                  batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# re_lu_81 (ReLU)                 (None, 50, 64)       0           add_45[0][0]
# __________________________________________________________________________________________________
# re_lu_84 (ReLU)                 (None, 50, 64)       0           add_46[0][0]
# __________________________________________________________________________________________________
# re_lu_87 (ReLU)                 (None, 50, 64)       0           add_47[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, 50, 64)       0           re_lu_81[0][0]
#                                                                  re_lu_84[0][0]
#                                                                  re_lu_87[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_10 (Gl (None, 64)           0           add_48[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 6)            390         global_average_pooling1d_10[0][0]
# ==================================================================================================
# Total params: 376,665
# Trainable params: 374,233
# Non-trainable params: 2,432
# __________________________________________________________________________________________________

# %%
import tensorflow
tensorflow.keras.utils.plot_model(model4, show_shapes=True, to_file='multichannel.png')

# %%
batch_size=1024
history4 = model4.fit(X_train, y_train, epochs=30, validation_split=0.25,batch_size=batch_size,verbose=1)
# Out:
# Train on 65889 samples, validate on 21963 samples
# Epoch 1/30
# 65889/65889 [==============================] - 11s 161us/sample - loss: 0.6663 - accuracy: 0.8083 - val_loss: 2.2855 - val_accuracy: 0.5830
# Epoch 2/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.2016 - accuracy: 0.9324 - val_loss: 0.6046 - val_accuracy: 0.8195
# Epoch 3/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.1442 - accuracy: 0.9520 - val_loss: 0.3404 - val_accuracy: 0.8723
# Epoch 4/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.1092 - accuracy: 0.9643 - val_loss: 0.2007 - val_accuracy: 0.9262
# Epoch 5/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0896 - accuracy: 0.9705 - val_loss: 0.2677 - val_accuracy: 0.9110
# Epoch 6/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.0720 - accuracy: 0.9764 - val_loss: 0.2039 - val_accuracy: 0.9302
# Epoch 7/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0629 - accuracy: 0.9793 - val_loss: 0.1858 - val_accuracy: 0.9412
# Epoch 8/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0501 - accuracy: 0.9842 - val_loss: 0.1493 - val_accuracy: 0.9536
# Epoch 9/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.0450 - accuracy: 0.9850 - val_loss: 0.2327 - val_accuracy: 0.9379
# Epoch 10/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0340 - accuracy: 0.9895 - val_loss: 0.1938 - val_accuracy: 0.9450
# Epoch 11/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.0319 - accuracy: 0.9899 - val_loss: 0.1995 - val_accuracy: 0.9481
# Epoch 12/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0302 - accuracy: 0.9906 - val_loss: 0.1604 - val_accuracy: 0.9569
# Epoch 13/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0198 - accuracy: 0.9941 - val_loss: 0.1455 - val_accuracy: 0.9615
# Epoch 14/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.2255 - val_accuracy: 0.9473
# Epoch 15/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.1623 - val_accuracy: 0.9593
# Epoch 16/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.2012 - val_accuracy: 0.9474
# Epoch 17/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0184 - accuracy: 0.9940 - val_loss: 0.2007 - val_accuracy: 0.9506
# Epoch 18/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0139 - accuracy: 0.9957 - val_loss: 0.1732 - val_accuracy: 0.9589
# Epoch 19/30
# 65889/65889 [==============================] - 5s 72us/sample - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.1525 - val_accuracy: 0.9651
# Epoch 20/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.0158 - accuracy: 0.9951 - val_loss: 0.3689 - val_accuracy: 0.9282
# Epoch 21/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.1713 - val_accuracy: 0.9613
# Epoch 22/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.1726 - val_accuracy: 0.9606
# Epoch 23/30
# 65889/65889 [==============================] - 5s 70us/sample - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.1987 - val_accuracy: 0.9598
# Epoch 24/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.1711 - val_accuracy: 0.9634
# Epoch 25/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.1864 - val_accuracy: 0.9604
# Epoch 26/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.1630 - val_accuracy: 0.9644
# Epoch 27/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.2288 - val_accuracy: 0.9514
# Epoch 28/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.1599 - val_accuracy: 0.9655
# Epoch 29/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0088 - accuracy: 0.9973 - val_loss: 0.1919 - val_accuracy: 0.9611
# Epoch 30/30
# 65889/65889 [==============================] - 5s 71us/sample - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.1631 - val_accuracy: 0.9665

# %%
display_history(history4)
plot_metrices(model4)
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.88      0.91      0.89      2012
#      Jogging       0.97      0.99      0.98      6940
#      Sitting       0.98      0.99      0.99      1226
#     Standing       0.98      0.99      0.98       969
#     Upstairs       0.95      0.83      0.88      2439
#      Walking       0.98      0.99      0.98      8378
#
#     accuracy                           0.96     21964
#    macro avg       0.96      0.95      0.95     21964
# weighted avg       0.96      0.96      0.96     21964
#
# ACC: 0.9646
# Sensitivity: 0.9749
# Specificity: 0.9975

# %%
import sklearn.metrics
def plot_roc(model_, name):
    plt.figure()
    ax = plt.subplot()
    ax.set_title('ROC Curve')
    pred = model_.predict(X_test).ravel()
    print(pred.size)
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test.ravel(), pred)
    ac = sklearn.metrics.auc(fpr, tpr)
    plt.figure(1)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='{} (area = {:.3f})'.format(name, ac))
    plt.xlabel('False positive rate(100-Specificity)')
    plt.ylabel('True positive rate(Sensitivity)')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show
plot_roc(model4,"WISNet")
# Out:
# 131784
